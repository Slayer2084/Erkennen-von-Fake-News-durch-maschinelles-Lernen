# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FeatureUnion
from gensim.sklearn_api import W2VTransformer
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer


def get_feature_union(df):
    text_vect_pipe = ColumnTransformer([
        ("Word2Vec", TfidfVectorizer(stop_words="english", ngram_range=[1, 3], strip_accents=None,
                                lowercase=False, smooth_idf=False, analyzer="char", use_idf=True,
                                sublinear_tf=True, norm="l2", binary=True), ["content", "lemmatized", "removed_names",
                                        "converted_emojis", "removed_rare_words"]),
    ])

    num_pipe = ColumnTransformer([
        ("Scaler", RobustScaler(), ["likeCount", "quoteCount", "retweetCount", "replyCount", "nHashtags",
                                    "nMentionedUsers", "opFollowerCount", "opFollowingCount", "opPostedTweetsCount",
                                    "opFavouritesCount", "opListedCount", "polarity", "subjectivity", "char_count",
                                    "verb_count", "noun_count", "adj_count", "word_count", "sent_count", "avg_word_len",
                                    "avg_sent_len", "num_rare_words", "num_lemmatized_words", "num_rare_words"])
    ])

    tag_pipe = ColumnTransformer([
        ("Scaler", RobustScaler(), [k for k in df.columns if 'tags_' in k])
    ])

    hot_encoded_pipe = ColumnTransformer([
        ("OneHotEncoder", OneHotEncoder(), ["source", "hashtags", "shortened_outlinks"])
    ])

    pipe = FeatureUnion([
        ("text_features", text_vect_pipe),
        ("numerical_features", num_pipe),
        ("tag_features", tag_pipe),
        ("hot_encoded_features", hot_encoded_pipe)
    ])
    return pipe

# %%
from CombineDatasets import get_combined_dataset
from FeatureEngineering import get_features
df = get_combined_dataset()
df = get_features(df.sample(10))
X = df.drop("label", axis="columns")
y = df["label"]
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["time"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.date)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["likeCount"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.likeCount)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["quoteCount"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.quoteCount)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["source"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.sourceLabel)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["retweetCount"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.retweetCount)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["replyCount"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.replyCount)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["op_object"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.user)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["hashtags"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.hashtags)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["nHashtags"] = df_ft["tweet_object"].apply(
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["mentionedUsers"] = df_ft["tweet_object"].apply(lambda tweet: None if tweet is None else tweet.mentionedUsers)
# C:\Users\slaye\PycharmProjects\FakeNews\FeatureEngineering.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ft["nMentionedUsers"] = df_ft["tweet_object"].apply(
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\slaye\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\slaye\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# get_features function took 42307.809 ms

# %%
pipe = get_feature_union(df)
pipe.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\utils\_encode.py in _unique_python(values, return_inverse)
#     131     try:
# --> 132         uniques_set = set(values)
#     133         uniques_set, missing_values = _extract_missing(uniques_set)
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16608/486195966.py in <module>
#       1 pipe = get_feature_union(df)
# ----> 2 pipe.fit(X, y)
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#    1141             FeatureUnion class instance.
#    1142         """
# -> 1143         transformers = self._parallel_func(X, y, fit_params, _fit_one)
#    1144         if not transformers:
#    1145             # All transformers are None
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\pipeline.py in _parallel_func(self, X, y, fit_params, func)
#    1192         transformers = list(self._iter())
#    1193
# -> 1194         return Parallel(n_jobs=self.n_jobs)(
#    1195             delayed(func)(
#    1196                 transformer,
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     209     def __call__(self, *args, **kwargs):
#     210         with config_context(**self.config):
# --> 211             return self.function(*args, **kwargs)
#     212
#     213
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\pipeline.py in _fit_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     905     """
#     906     with _print_elapsed_time(message_clsname, message):
# --> 907         return transformer.fit(X, y, **fit_params)
#     908
#     909
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\compose\_column_transformer.py in fit(self, X, y)
#     640         # we use fit_transform to make sure to set sparse_output_ (for which we
#     641         # need the transformed data) to have consistent output type in predict
# --> 642         self.fit_transform(X, y=y)
#     643         return self
#     644
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     673         self._validate_remainder(X)
#     674
# --> 675         result = self._fit_transform(X, y, _fit_transform_one)
#     676
#     677         if not result:
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\compose\_column_transformer.py in _fit_transform(self, X, y, func, fitted, column_as_strings)
#     604         )
#     605         try:
# --> 606             return Parallel(n_jobs=self.n_jobs)(
#     607                 delayed(func)(
#     608                     transformer=clone(trans) if not fitted else trans,
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     209     def __call__(self, *args, **kwargs):
#     210         with config_context(**self.config):
# --> 211             return self.function(*args, **kwargs)
#     212
#     213
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     486         """
#     487         self._validate_keywords()
# --> 488         return super().fit_transform(X, y)
#     489
#     490     def transform(self, X):
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     848         else:
#     849             # fit method of arity 2 (supervised transformation)
# --> 850             return self.fit(X, y, **fit_params).transform(X)
#     851
#     852
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     459         """
#     460         self._validate_keywords()
# --> 461         self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#     462         self.drop_idx_ = self._compute_drop_idx()
#     463         return self
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown, force_all_finite)
#      92             Xi = X_list[i]
#      93             if self.categories == "auto":
# ---> 94                 cats = _unique(Xi)
#      95             else:
#      96                 cats = np.array(self.categories[i], dtype=Xi.dtype)
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\utils\_encode.py in _unique(values, return_inverse)
#      29     """
#      30     if values.dtype == object:
# ---> 31         return _unique_python(values, return_inverse=return_inverse)
#      32     # numerical
#      33     out = np.unique(values, return_inverse=return_inverse)
#
# c:\users\slaye\pycharmprojects\fakenews\lib\site-packages\sklearn\utils\_encode.py in _unique_python(values, return_inverse)
#     138     except TypeError:
#     139         types = sorted(t.__qualname__ for t in set(type(v) for v in values))
# --> 140         raise TypeError(
#     141             "Encoders require their input to be uniformly "
#     142             f"strings or numbers. Got {types}"
#
# TypeError: Encoders require their input to be uniformly strings or numbers. Got ['NoneType', 'list']
